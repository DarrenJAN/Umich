# %%
using Random: seed!
using Statistics
using Plots
using Distances
using LinearAlgebra

# %%
"""
x = lsgd(A, b ; mu=0, x0=zeros(size(A,2)), nIters::Int=200)
Performs gradient descent to solve the least squares problem:
``\\argmin_x 0.5 \\| b − A x \\|_2``
In:
− `A` `m × n` matrix
− `b` vector of length `m`
Option:
− `mu` step size to use, and must satisfy ``0 < mu < 2 / \\sigma_1(A)^2``
to guarantee convergence,
where ``\\sigma_1(A)`` is the first (largest) singular value.
Ch.5 will explain a default value for `mu`
− `x0` is the initial starting vector (of length `n`) to use.
Its default value is all zeros for simplicity.
− `nIters` is the number of iterations to perform (default 200)
Out:
− `x` vector of length `n` containing the approximate LS solution
"""
function lsgd(A, b, mu, x0, nIters)
    x_hat = pinv(A)*b
    x_next= zeros(size(A,2))
    x_current = x0
    x =[1:nIters;]
    y = []
    for i in 1:nIters 
        x_next = x_current - mu * A' * (A * x_current - b)
        x_current = x_next
        a = log(10, euclidean(x_current, x_hat))
        display(euclidean(x_current, x_hat))
        push!(y, a)
    end 
    return x_next, x, y
end
# Out:
# lsgd

# %%
function lsgd(A, b ; mu::Real=0, x0=zeros(size(A,2)), nIters::Int=200)
    x_next= zeros(size(A,2))
    x_current = x0
    for i in 1:nIters 
        x_next = x_current - mu * A' * (A * x_current - b)
        x_current = x_next
    end 
    return x_next
end
# Out:
# lsgd (generic function with 2 methods)

# %%
"""
part(b)
"""



using Random: seed!
m = 100; n = 50; sigma = 0.1
seed!(0) # seed random number generator
A = randn(m, n); xtrue = rand(n); noise = randn(m)
b = A * xtrue + sigma * noise # b and xhat change when sigma changes

_,s,_=svd(A)
sigma1=1/(s[1]^2)
#mu=sigma1
k=LinRange(0,199,200)

y1=zeros(200)
for i=1:200
    y1[i]=log10(norm(lsgd(A,b,nIters=i,mu=sigma1)-xtrue))
end

plot(xlabel = "k")
plot!(ylabel = "log10(||xk-xh||)")
plot!(k,y1, label ="sigma = 0.1")
#plot!(k,A2*x2h,label="p2(t)")

# %%
sigma = 0.5
b = A * xtrue + sigma * noise # b and xhat change when sigma changes
y2=zeros(200)

for i=1:200
    y2[i]=log10(norm(lsgd(A,b,nIters=i,mu=sigma1)-xtrue))
end

plot!(k,y2, label ="sigma = 0.5")

# %%
sigma = 1
A = randn(m, n); xtrue = rand(n); noise = randn(m)
b = A * xtrue + sigma * noise # b and xhat change when sigma changes
x0=zeros(size(A,2))
x_hat = pinv(A)*b
mu = 1/ std(A)^2
x_k, x, y = lsgd(A, b, mu, x0, k)
plot!(x, y, xlabel = "k", label ="sigma = 1")
# Out:
# MethodError: no method matching (::Colon)(::Int64, ::LinRange{Float64})
# Closest candidates are:
#   (::Colon)(::T, ::Any, ::T) where T<:Real at range.jl:41
#   (::Colon)(::A, ::Any, ::C) where {A<:Real, C<:Real} at range.jl:10
#   (::Colon)(::T, ::Any, ::T) where T at range.jl:40
#   ...
#
# Stacktrace:
#  [1] lsgd(A::Matrix{Float64}, b::Vector{Float64}, mu::Float64, x0::Vector{Float64}, nIters::LinRange{Float64})
#    @ Main ./In[2]:23
#  [2] top-level scope
#    @ In[15]:7
#  [3] eval
#    @ ./boot.jl:360 [inlined]
#  [4] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
sigma = 2
A = randn(m, n); xtrue = rand(n); noise = randn(m)
b = A * xtrue + sigma * noise # b and xhat change when sigma changes
x0=zeros(size(A,2))
x_hat = pinv(A)*b
mu = 1/ std(A)^2
x_k, x, y = lsgd(A, b, mu, x0, k)
plot!(x, y, xlabel = "k", label ="sigma = 2")

# %%
y
# Out:
# 125-element Vector{Any}:
#   2.853564025551748
#   5.2069032549073775
#   7.602049069886447
#  10.014954568953739
#  12.437353462857882
#  14.865522250315355
#  17.297419757012484
#  19.731788951960116
#  22.16781466787137
#  24.604957095587775
#  27.04285535716271
#  29.481266843505907
#  31.92002777505612
#   ⋮
#  Inf
#  Inf
#  Inf
#  Inf
#  Inf
#  Inf
#  Inf
#  Inf
#  Inf
#  Inf
#  Inf
#  Inf
